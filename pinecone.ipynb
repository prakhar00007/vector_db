# %% [markdown]
# <a href="https://colab.research.google.com/github/prakhar00007/vector_db/blob/main/pinecone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pinecone

# %%
import pinecone
pinecone.__version__
# Out:
# '8.0.0'

# %%
from pinecone import Pinecone, ServerlessSpec

# %%
documents = [
    {
        "id": "doc-001",
        "text": "Pinecone is a fully managed vector database for search and recommendation.",
        "category": "documentation",
        "tag": "pinecone",
        "difficulty": "beginner",
        "url": "https://example.com/pinecone-intro"
    },
    {
        "id": "doc-002",
        "text": "To use Pinecone with Python, you create an index and upsert vectors with metadata.",
        "category": "documentation",
        "tag": "python",
        "difficulty": "beginner",
        "url": "https://example.com/pinecone-python"
    },
    {
        "id": "doc-003",
        "text": "Vector databases store embeddings that capture semantic meaning for semantic search.",
        "category": "blog",
        "tag": "vector-db",
        "difficulty": "intermediate",
        "url": "https://example.com/vector-db-concepts"
    },
    {
        "id": "doc-004",
        "text": "You can filter Pinecone search results using metadata such as category or difficulty.",
        "category": "faq",
        "tag": "metadata",
        "difficulty": "beginner",
        "url": "https://example.com/pinecone-metadata"
    },
    {
        "id": "doc-005",
        "text": "In Retrieval-Augmented Generation, a vector database like Pinecone stores document chunks.",
        "category": "blog",
        "tag": "rag",
        "difficulty": "intermediate",
        "url": "https://example.com/rag-pinecone"
    }
]

# %%
pc = Pinecone(api_key="YOUR_API_KEY")

# %%
pc

# %%
import requests
import numpy as np
from typing import List, Union

EURON_API_KEY = "YOUR_API_KEY"

def generate_embeddings(texts: Union[str, List[str]]):
    # Always make the input a list
    if isinstance(texts, str):
        texts = [texts]

    url = "https://api.euron.one/api/v1/euri/embeddings"
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {EURON_API_KEY}"
    }
    payload = {
        "input": texts,
        "model": "text-embedding-3-small"
    }

    response = requests.post(url, headers=headers, json=payload)
    data = response.json()

    # Convert each embedding to numpy array
    embeddings = [np.array(item["embedding"], dtype=np.float32) for item in data["data"]]

    # Return single vector OR batch of vectors
    return embeddings[0] if len(embeddings) == 1 else np.stack(embeddings)

# %%
INDEX_NAME = "euron-pinecone-euri-demo"

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "euron-pinecone-euri-demo",
#         "metric": "cosine",
#         "host": "euron-pinecone-euri-demo-gftomil.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1536,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
pc.create_index(
    name = INDEX_NAME,
    dimension = 1536,
    metric = "cosine",
    spec = ServerlessSpec(
        cloud = "aws",
        region = "us-east-1"))
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
# /tmp/ipython-input-3900509328.py in <cell line: 0>()
# ----> 1 pc.create_index(
#       2     name = INDEX_NAME,
#       3     dimension = 1536,
#       4     metric = "cosine",
#       5     spec = ServerlessSpec(
#
# /usr/local/lib/python3.12/dist-packages/pinecone/pinecone.py in create_index(self, name, spec, dimension, metric, timeout, deletion_protection, vector_type, tags)
#     497
#     498         """
# --> 499         return self.db.index.create(
#     500             name=name,
#     501             spec=spec,
#
# /usr/local/lib/python3.12/dist-packages/pinecone/utils/require_kwargs.py in wrapper(*args, **kwargs)
#      24                 f"Please use {func.__name__}({', '.join(f'{name}=value' for name in param_names)})"
#      25             )
# ---> 26         return func(*args, **kwargs)
#      27
#      28     return wrapper
#
# /usr/local/lib/python3.12/dist-packages/pinecone/db_control/resources/sync/index.py in create(self, name, spec, dimension, metric, timeout, deletion_protection, vector_type, tags)
#      93             tags=tags,
#      94         )
# ---> 95         resp = self._index_api.create_index(create_index_request=req)
#      96
#      97         if timeout == -1:
#
# /usr/local/lib/python3.12/dist-packages/pinecone/openapi_support/endpoint.py in __call__(self, *args, **kwargs)
#     100
#     101         """
# --> 102         return self.callable(self, *args, **kwargs)
#     103
#     104     def call_with_http_info(self, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pinecone/core/openapi/db_control/api/manage_indexes_api.py in __create_index(self, create_index_request, x_pinecone_api_version, **kwargs)
#     373             kwargs["x_pinecone_api_version"] = x_pinecone_api_version
#     374             kwargs["create_index_request"] = create_index_request
# --> 375             return cast(IndexModel | ApplyResult[IndexModel], self.call_with_http_info(**kwargs))
#     376
#     377         self.create_index = _Endpoint(
#
# /usr/local/lib/python3.12/dist-packages/pinecone/openapi_support/endpoint.py in call_with_http_info(self, **kwargs)
#     132         HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
#     133
# --> 134         return self.api_client.call_api(
#     135             self.settings["endpoint_path"],
#     136             self.settings["http_method"],
#
# /usr/local/lib/python3.12/dist-packages/pinecone/openapi_support/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     318
#     319         if not async_req:
# --> 320             return self.__call_api(
#     321                 resource_path,
#     322                 method,
#
# /usr/local/lib/python3.12/dist-packages/pinecone/openapi_support/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     183         except PineconeApiException as e:
#     184             e.body = e.body.decode("utf-8")
# --> 185             raise e
#     186
#     187         self.last_response = response_data
#
# /usr/local/lib/python3.12/dist-packages/pinecone/openapi_support/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     171         try:
#     172             # perform request and return response
# --> 173             response_data = self.request(
#     174                 method,
#     175                 url,
#
# /usr/local/lib/python3.12/dist-packages/pinecone/openapi_support/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     398             )
#     399         elif method == "POST":
# --> 400             return self.rest_client.POST(
#     401                 url,
#     402                 query_params=query_params,
#
# /usr/local/lib/python3.12/dist-packages/pinecone/openapi_support/rest_utils.py in POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     144         _request_timeout=None,
#     145     ):
# --> 146         return self.request(
#     147             "POST",
#     148             url,
#
# /usr/local/lib/python3.12/dist-packages/pinecone/openapi_support/rest_urllib3.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     268             logger.debug("response body: %s", r.data)
#     269
# --> 270         return raise_exceptions_or_return(r)
#
# /usr/local/lib/python3.12/dist-packages/pinecone/openapi_support/rest_utils.py in raise_exceptions_or_return(r)
#      47             raise ServiceException(http_resp=r)
#      48
# ---> 49         raise PineconeApiException(http_resp=r)
#      50
#      51     return r
#
# PineconeApiException: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'content-type': 'text/plain; charset=utf-8', 'access-control-allow-origin': '*', 'vary': 'origin,access-control-request-method,access-control-request-headers', 'access-control-expose-headers': '*', 'x-pinecone-api-version': '2025-10', 'x-cloud-trace-context': 'ce982789d9dadb5ab4c26a5f85bb12f3', 'date': 'Mon, 08 Dec 2025 09:05:25 GMT', 'server': 'Google Frontend', 'Content-Length': '85', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: {"error":{"code":"ALREADY_EXISTS","message":"Resource  already exists"},"status":409}

# %%
documents
# Out:
# [{'id': 'doc-001',
#   'text': 'Pinecone is a fully managed vector database for search and recommendation.',
#   'category': 'documentation',
#   'tag': 'pinecone',
#   'difficulty': 'beginner',
#   'url': 'https://example.com/pinecone-intro'},
#  {'id': 'doc-002',
#   'text': 'To use Pinecone with Python, you create an index and upsert vectors with metadata.',
#   'category': 'documentation',
#   'tag': 'python',
#   'difficulty': 'beginner',
#   'url': 'https://example.com/pinecone-python'},
#  {'id': 'doc-003',
#   'text': 'Vector databases store embeddings that capture semantic meaning for semantic search.',
#   'category': 'blog',
#   'tag': 'vector-db',
#   'difficulty': 'intermediate',
#   'url': 'https://example.com/vector-db-concepts'},
#  {'id': 'doc-004',
#   'text': 'You can filter Pinecone search results using metadata such as category or difficulty.',
#   'category': 'faq',
#   'tag': 'metadata',
#   'difficulty': 'beginner',
#   'url': 'https://example.com/pinecone-metadata'},
#  {'id': 'doc-005',
#   'text': 'In Retrieval-Augmented Generation, a vector database like Pinecone stores document chunks.',
#   'category': 'blog',
#   'tag': 'rag',
#   'difficulty': 'intermediate',
#   'url': 'https://example.com/rag-pinecone'}]

# %%
documents[0]['text']
# Out:
# 'Pinecone is a fully managed vector database for search and recommendation.'

# %%
texts=[doc['text'] for doc in documents]

# %%
texts
# Out:
# ['Pinecone is a fully managed vector database for search and recommendation.',
#  'To use Pinecone with Python, you create an index and upsert vectors with metadata.',
#  'Vector databases store embeddings that capture semantic meaning for semantic search.',
#  'You can filter Pinecone search results using metadata such as category or difficulty.',
#  'In Retrieval-Augmented Generation, a vector database like Pinecone stores document chunks.']

# %%
doc_embeddings=generate_embeddings(texts)

# %%
doc_embeddings
# Out:
# array([[-0.001367  ,  0.00097596,  0.02587722, ...,  0.01030115,
#         -0.00445685, -0.00447976],
#        [ 0.02906471,  0.02790113,  0.04518151, ..., -0.01396294,
#          0.00476263,  0.01302218],
#        [-0.02904676,  0.02357966,  0.01055084, ...,  0.02753553,
#          0.00489206,  0.0044698 ],
#        [ 0.02287637, -0.01052978,  0.05373645, ..., -0.00688338,
#          0.02043264, -0.01085604],
#        [ 0.01344805,  0.02365223,  0.04482685, ..., -0.00082055,
#          0.04612951,  0.01821171]], dtype=float32)

# %%
for doc,emb in zip(documents , doc_embeddings):
  print(doc,emb)
# Out:
# {'id': 'doc-001', 'text': 'Pinecone is a fully managed vector database for search and recommendation.', 'category': 'documentation', 'tag': 'pinecone', 'difficulty': 'beginner', 'url': 'https://example.com/pinecone-intro'} [-0.001367    0.00097596  0.02587722 ...  0.01030115 -0.00445685
#  -0.00447976]
# {'id': 'doc-002', 'text': 'To use Pinecone with Python, you create an index and upsert vectors with metadata.', 'category': 'documentation', 'tag': 'python', 'difficulty': 'beginner', 'url': 'https://example.com/pinecone-python'} [ 0.02906471  0.02790113  0.04518151 ... -0.01396294  0.00476263
#   0.01302218]
# {'id': 'doc-003', 'text': 'Vector databases store embeddings that capture semantic meaning for semantic search.', 'category': 'blog', 'tag': 'vector-db', 'difficulty': 'intermediate', 'url': 'https://example.com/vector-db-concepts'} [-0.02904676  0.02357966  0.01055084 ...  0.02753553  0.00489206
#   0.0044698 ]
# {'id': 'doc-004', 'text': 'You can filter Pinecone search results using metadata such as category or difficulty.', 'category': 'faq', 'tag': 'metadata', 'difficulty': 'beginner', 'url': 'https://example.com/pinecone-metadata'} [ 0.02287637 -0.01052978  0.05373645 ... -0.00688338  0.02043264
#  -0.01085604]
# {'id': 'doc-005', 'text': 'In Retrieval-Augmented Generation, a vector database like Pinecone stores document chunks.', 'category': 'blog', 'tag': 'rag', 'difficulty': 'intermediate', 'url': 'https://example.com/rag-pinecone'} [ 0.01344805  0.02365223  0.04482685 ... -0.00082055  0.04612951
#   0.01821171]

# %%
vector_to_upsert = []
for doc,emb in  zip(documents, doc_embeddings):
    metadata = {
        "category": doc["category"],
        "tag": doc["tag"],
        "difficulty": doc["difficulty"],
        "url": doc["url"],
        "text": doc["text"]
        }
    vector_item = {
        "id": doc["id"],
        "values": emb.tolist(),
        "metadata": metadata
    }

    vector_to_upsert.append(vector_item)

# %%
vector_to_upsert

# %%
vector_to_upsert[0]['metadata']
# Out:
# {'category': 'documentation',
#  'tag': 'pinecone',
#  'difficulty': 'beginner',
#  'url': 'https://example.com/pinecone-intro',
#  'text': 'Pinecone is a fully managed vector database for search and recommendation.'}

# %%
index = pc.Index(INDEX_NAME)

# %%
index

# %%
INDEX_NAME
# Out:
# 'euron-pinecone-euri-demo'

# %%
index.upsert(vectors=vector_to_upsert)
# Out:
# UpsertResponse(upserted_count=5, _response_info={'raw_headers': {'date': 'Mon, 08 Dec 2025 09:35:02 GMT', 'content-type': 'application/json', 'content-length': '19', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '1', 'x-pinecone-request-logical-size': '31805', 'x-pinecone-request-latency-ms': '278', 'x-pinecone-request-id': '7682488162771850726', 'x-envoy-upstream-service-time': '268', 'grpc-status': '0', 'server': 'envoy'}})

# %%
query_text = "How to use Pinecone with Python?"
query_embedding = generate_embeddings(query_text)

# %%
query_embedding
# Out:
# array([ 0.00058833, -0.03537055,  0.04636481, ..., -0.01094834,
#        -0.01569109,  0.03009645], dtype=float32)

# %%
query_request={
    "vector":query_embedding.tolist(),
    "top_k":3,
    "include_metadata":True
}

# %%
index.query(**query_request)
# Out:
# QueryResponse(matches=[{'id': 'doc-002',
#  'metadata': {'category': 'documentation',
#               'difficulty': 'beginner',
#               'tag': 'python',
#               'text': 'To use Pinecone with Python, you create an index and '
#                       'upsert vectors with metadata.',
#               'url': 'https://example.com/pinecone-python'},
#  'score': 0.702996254,
#  'values': []}, {'id': 'doc-001',
#  'metadata': {'category': 'documentation',
#               'difficulty': 'beginner',
#               'tag': 'pinecone',
#               'text': 'Pinecone is a fully managed vector database for search '
#                       'and recommendation.',
#               'url': 'https://example.com/pinecone-intro'},
#  'score': 0.566223145,
#  'values': []}, {'id': 'doc-004',
#  'metadata': {'category': 'faq',
#               'difficulty': 'beginner',
#               'tag': 'metadata',
#               'text': 'You can filter Pinecone search results using metadata '
#                       'such as category or difficulty.',
#               'url': 'https://example.com/pinecone-metadata'},
#  'score': 0.493413,
#  'values': []}], namespace='', usage={'read_units': 1}, _response_info={'raw_headers': {'date': 'Mon, 08 Dec 2025 09:43:40 GMT', 'content-type': 'application/json', 'content-length': '844', 'connection': 'keep-alive', 'x-pinecone-max-indexed-lsn': '1', 'x-pinecone-request-latency-ms': '58', 'x-pinecone-request-id': '9001775818173460183', 'x-envoy-upstream-service-time': '56', 'grpc-status': '0', 'server': 'envoy'}})

# %%
pi_response_meta = index.query(
    vector=query_embedding.tolist(),
    top_k=3,
    include_metadata=True,
    filter={
        "difficulty": {"$eq": "beginner"}}
)

# %%
pi_response_meta
# Out:
# QueryResponse(matches=[{'id': 'doc-002',
#  'metadata': {'category': 'documentation',
#               'difficulty': 'beginner',
#               'tag': 'python',
#               'text': 'To use Pinecone with Python, you create an index and '
#                       'upsert vectors with metadata.',
#               'url': 'https://example.com/pinecone-python'},
#  'score': 0.702996254,
#  'values': []}, {'id': 'doc-001',
#  'metadata': {'category': 'documentation',
#               'difficulty': 'beginner',
#               'tag': 'pinecone',
#               'text': 'Pinecone is a fully managed vector database for search '
#                       'and recommendation.',
#               'url': 'https://example.com/pinecone-intro'},
#  'score': 0.566223145,
#  'values': []}, {'id': 'doc-004',
#  'metadata': {'category': 'faq',
#               'difficulty': 'beginner',
#               'tag': 'metadata',
#               'text': 'You can filter Pinecone search results using metadata '
#                       'such as category or difficulty.',
#               'url': 'https://example.com/pinecone-metadata'},
#  'score': 0.493413,
#  'values': []}], namespace='', usage={'read_units': 1}, _response_info={'raw_headers': {'date': 'Mon, 08 Dec 2025 09:48:04 GMT', 'content-type': 'application/json', 'content-length': '844', 'connection': 'keep-alive', 'x-pinecone-max-indexed-lsn': '1', 'x-pinecone-request-latency-ms': '36', 'x-pinecone-request-id': '1881642732961193659', 'x-envoy-upstream-service-time': '34', 'grpc-status': '0', 'server': 'envoy'}})
